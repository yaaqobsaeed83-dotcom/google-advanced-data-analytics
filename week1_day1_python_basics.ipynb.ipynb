# %%
week1_day1_python_basics.ipynb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 week1_day1_python_basics.ipynb
#
# NameError: name 'week1_day1_python_basics' is not defined

# %%
print("Week 1 Day 1 - ready")
# Out:
# Week 1 Day 1 - ready
